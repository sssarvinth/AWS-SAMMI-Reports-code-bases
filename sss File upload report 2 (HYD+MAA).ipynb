# %%
##view RAW Data
import pandas as pd
import numpy as np
df= pd.read_excel(r'C:\Users\arvinmvn\Desktop\AWS SAMI Reports\MAA\AWS MAA Verifers File Upload Report(for @arvinmvn)\AWS Verification File Upload Report W45.xlsx',)
df.head()
# Out:
#     User ID  Audio Length  Velocity Quip  Quality Quip Site     TM
# 0  Amznsram  00:00:04.944            NaN           1.0  MAA  czvij
# 1     djaga  00:00:09.320            NaN           1.0  MAA  czvij
# 2     djaga  00:01:18.440            NaN           1.0  MAA  czvij
# 3     djaga  00:01:06.620            NaN           1.0  MAA  czvij
# 4     djaga  00:00:13.740            NaN           1.0  MAA  czvij

# %%
df.insert(2, "File Count", 1)
df.head()
# Out:
#     User ID  Audio Length  File Count  Velocity Quip  Quality Quip Site     TM
# 0  Amznsram  00:00:04.944           1            NaN           1.0  MAA  czvij
# 1     djaga  00:00:09.320           1            NaN           1.0  MAA  czvij
# 2     djaga  00:01:18.440           1            NaN           1.0  MAA  czvij
# 3     djaga  00:01:06.620           1            NaN           1.0  MAA  czvij
# 4     djaga  00:00:13.740           1            NaN           1.0  MAA  czvij

# %%
df.columns
# Out:
# Index(['User ID', 'Audio Length', 'File Count', 'Velocity Quip',
#        'Quality Quip', 'Site', 'TM'],
#       dtype='object')

# %%
##pivot for file counts
table = pd.pivot_table(df, values=['Velocity Quip', 'Quality Quip'], index=['User ID','TM'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
pd.set_option('display.max_rows', df.shape[0]+1)
table
# Out:
#                   Quality Quip  Velocity Quip
# User ID  TM
# Amznsram czvij              82              0
# cliffpal czvij              69             90
# dennypau czvij              43             42
# djaga    czvij              89             89
# dogiboin latikat            42             59
# gopinana czvij              83             83
# jhus     czvij              79             79
# keerdoss czvij              41             41
# mmzsai   czvij              56             55
# pdikcha  czvij              41             60
# utasneem latikat            38             38
# vsreevat czvij              41             78

# %%
##create list of DA names


table_AL = pd.pivot_table(df, values=['Velocity Quip', 'Quality Quip'], index=['User ID','Audio Length','TM'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
pd.set_option('display.max_rows', df.shape[0]+1)
table_AL
# Out:
#                                Quality Quip  Velocity Quip
# User ID  Audio Length TM
# Amznsram 00:00:00.648 czvij               1              0
#          00:00:00.686 czvij               1              0
#          00:00:01.586 czvij               1              0
#          00:00:02.275 czvij               1              0
#          00:00:03.168 czvij               1              0
#          00:00:03.265 czvij               1              0
#          00:00:03.578 czvij               1              0
#          00:00:03.933 czvij               1              0
#          00:00:04.266 czvij               1              0
#          00:00:04.440 czvij               1              0
#          00:00:04.944 czvij               1              0
#          00:00:05.459 czvij               1              0
#          00:00:05.568 czvij               1              0
#          00:00:07.300 czvij               1              0
# ...

# %%
df_hyd=df[df['TM']=='latikat']
df_maa=df[df['TM']=='czvij']

# %%
list_maa= df_maa['User ID'].unique().tolist()
list_maa
list_hyd= df_hyd['User ID'].unique().tolist()
list_hyd
# Out:
# ['utasneem', 'dogiboin']

# %%
## For MAA


##view pivot:- working code for pivoting the table with audio lenth in index as well sss
import win32com.client as win32
for i in range(0,len(list_maa)):
    table_maa = pd.pivot_table(df_maa[df_maa['User ID']== list_maa[i]], values=['Velocity Quip', 'Quality Quip'], index=['User ID','Audio Length'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
    pd.set_option('display.max_rows', df.shape[0]+1)
    #print(table_sss)
    ##email to DAs :- one click still in pipeline

    outlook = win32.Dispatch('outlook.application')
    mail = outlook.CreateItem(0)
    mail.Subject = 'AWS File Upload Report'
    #mail.To='arvinmvn@amazon.com'
    mail.To = list_maa[i]+'@amazon.com'  
    mail.CC = 'czvij@amazon.com'
    
## i-> position of data in dataframe
    mail.HTMLBody = '''<h3>Hi, Please find your file uploads for the week.</h3>
                   {}'''.format(table_maa.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render())  ## : i + 1 increment 1 of index 
# To attach a file to the email (optional):
#attachment  = "Path to the attachment"
#mail.Attachments.Add(attachment)

    mail.Send()

# %%
## For HYD

##view pivot:- working code for pivoting the table with audio lenth in index as well sss
import win32com.client as win32
for i in range(0,len(list_hyd)):
    table_hyd = pd.pivot_table(df_hyd[df_hyd['User ID']== list_hyd[i]], values=['Velocity Quip', 'Quality Quip'], index=['User ID','Audio Length'], columns= [] ,margins=False,
               margins_name='total', aggfunc=sum , fill_value=0)
## display all options
    pd.set_option('display.max_rows', df.shape[0]+1)
    #print(table_sss)
    ##email to DAs :- one click still in pipeline

    outlook = win32.Dispatch('outlook.application')
    mail = outlook.CreateItem(0)
    mail.Subject = 'AWS File Upload Report'
    #mail.To='arvinmvn@amazon.com'
    mail.To = list_hyd[i]+'@amazon.com'  
    mail.CC = 'latikat@amazon.com'
    
## i-> position of data in dataframe
    mail.HTMLBody = '''<h3>Hi, Please find your file uploads for the week.</h3>
                   {}'''.format(table_hyd.style.set_table_styles(
[{'selector': 'th',
  'props': [('background', '#F5F5F5'), 
            ('color', 'black'),
            ('font-family', 'verdana'),
            ('border-style','double'),
            ('border-width','thin'),
           ('font-weight', 'normal'),
           ('text-align','center')]},
 
 {'selector': 'td',
  'props': [('font-family', 'verdana'),
           ('border-style','double'),
            ('border-width','thin'),
           ('text-align','center'),
           ('text-align','center')]},

 {'selector': 'tr:nth-of-type(odd)',
  'props': [('background', 'white')]}, 
 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'white')]},
 
 {'selector': 'tr:hover',
  'props': [('background-color', 'yellow')]}

]
).set_precision(2).render())  ## : i + 1 increment 1 of index 
# To attach a file to the email (optional):
#attachment  = "Path to the attachment"
#mail.Attachments.Add(attachment)

    mail.Send()
